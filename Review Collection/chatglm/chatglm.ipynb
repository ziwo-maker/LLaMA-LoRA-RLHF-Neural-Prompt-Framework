# %%
pip install protobuf==3.20.0 transformers==4.27.1 icetk cpm_kernels
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.3 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 416.6/416.6 kB 27.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.7 MB/s eta 0:00:0000:01
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.19.6
#     Uninstalling protobuf-3.19.6:
#       Successfully uninstalled protobuf-3.19.6
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 3.20.0 which is incompatible.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True)
model = AutoModel.from_pretrained("THUDM/chatglm-6b", trust_remote_code=True).half().cuda()
# Out:
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# ...
# Loading checkpoint shards:   0%|          | 0/8 [00:00<?, ?it/s]

# %%
import json
with open('data/lcstc/dataclean.json','r') as f:
        data_all=json.load(f)
ans=[];
for i in data_all:
    
    s="请将这句话提取出一个标题"+i["content"];
    
    response, history = model.chat(tokenizer, s, history=[])
    ans.append(response)
    print(response)
with open('lcsts.json','w') as f:
    json.dump(ans,f)
# Out:
# 修改后的《中华人民共和国立法法》全文播发，共有6章105条。
# 小轿车事故9死24伤，深圳市交警局通报司机超速行驶操作不当导致。目前24名伤员已有6名治愈出院，预计赔偿费或超一千万元。
# 习近平总书记对政法工作作出重要指示：为公正司法和提高执法司法公信力提供有力制度保障。
# "工信部约谈三大运营商，严查315晚会曝光电信行业乱象"
# "国家食药监管总局发布食品召回管理办法：食用后可能导致严重健康损害甚至死亡的属一级召回，食品生产者应在知悉食品安全风险后24小时内启动召回，且10个工作日内完成召回。"
# 标题：人民检察院刑事诉讼涉案财物管理规定
# 聂树斌案复查有新进展，山东高院通知聂树斌案申诉代理律师阅卷，这是10年来律师首次获准阅卷。此前，山东省高院复查聂树斌案合议庭成员提讯了王书金，其仍坚称石家庄西郊玉米地强奸杀人案是他所为。
# "北京市司法行政机关与检察机关联合召开人民监督员选任管理方式改革工作会议，宣布任命113名人民监督员，并组织监督员向宪法集体宣誓。人民监督员以‘第三方’监督方式，实现了检察院办案机制上的相互制衡。"
# 公共免费WIFI存在隐患，黑客可盗取用户个人信息，建议避免使用。
# 最高人民法院工作报告：纠正冤假错案 加强司法公正
# 新类型案件：手机代驾软件被判担责 for交通事故
# 标题：中央全面深化改革领导小组第十次会议审议通过了《深化人民监督员制度改革方案》，提出由司法行政机关负责人民监督员的选任和培训等管理工作，解决了检察机关“自己选人监督自己”的问题，使人民监督员的监督更有说服力。
# 标题：曝光“老赖”：欠钱不还者人人喊打，却无迹可寻，数量稀少难以执行
# 国家税务总局透露，去年税务协同公安等部门共查处发票违法犯罪案件10.2万起，抓获犯罪嫌疑人6014人，缴获假发票6449万份。其中税务部门查处违法企业9.9万户，查补税款106亿元，加收滞纳金10亿元，罚款和没收违法所得18亿元。
# 环保部决定对存在各类问题的63家建设项目环评机构和22名环评工程师作出相应处理，要求所有具有环保部门背景的环评单位全面退出建设项目环评技术服务市场，彻底解决“红顶中介”问题。
# ...

# %%
# Out:
# Archive:  data.zip
#    creating: data/
#    creating: data/.history/
#   inflating: data/.history/process_20230504164748.py
#   inflating: data/.history/process_20230505140043.py
#   inflating: data/.history/process_20230505140053.py
#   inflating: data/.history/process_20230505140144.py
#   inflating: data/.history/process_20230505153740.py
#   inflating: data/.history/process_20230505163503.py
#   inflating: data/.history/process_20230505221527.py
#    creating: data/c3/
#   inflating: data/c3/c3-d-dev.json
#   inflating: data/c3/dataclean.json
#   inflating: data/c3/readme.txt
#    creating: data/chid/
#   inflating: data/chid/dataclean.json
#   inflating: data/chid/dev_data.txt
#   inflating: data/chid/readme.txt
#   inflating: data/chid/test_data.txt
#    creating: data/generation/
#   inflating: data/generation/dataclean.json
#   inflating: data/generation/me_validation.ann.json
#  extracting: data/generation/readme.txt
#    creating: data/lcstc/
# ...

# %%
def do_math23():
    with open('data/math23/dataclean.json','r') as f:
        data_all=json.load(f)
    ans=[];
    path='math23_gpt_saved.json'
    right=0;
    wrong=0
    for i in data_all:
        s=i["original_text"];
        tmp, history = model.chat(tokenizer, s, history=[])
        ans.append(tmp)
        print("正确答案是"+i["ans"])
        if(i["ans"] in tmp):
            right=right+1
            print("此题正确")
        else:
            wrong=wrong+1
            print("此题错误")
    print(right*1.0/(right+wrong))
    print(right+wrong)
    with open(path,'w') as f:
        json.dump(ans,f);
        
do_math23();
# Out:
# 正确答案是880
# 此题错误
# 正确答案是14.4
# 此题错误
# 正确答案是150
# 此题错误
# 正确答案是6
# 此题错误
# 正确答案是4
# 此题正确
# 正确答案是50.24
# 此题错误
# 正确答案是240
# 此题错误
# 正确答案是451
# 此题错误
# 正确答案是180
# 此题错误
# 正确答案是35
# 此题错误
# 正确答案是1.5
# 此题错误
# 正确答案是260
# 此题错误
# 正确答案是700
# 此题错误
# 正确答案是344
# 此题错误
# 正确答案是60
# 此题错误
# 正确答案是((2)/(3))
# 此题错误
# 正确答案是15
# 此题错误
# 正确答案是41
# 此题错误
# 正确答案是20
# 此题错误
# 正确答案是18375
# 此题错误
# 正确答案是14
# 此题错误
# 正确答案是84
# 此题错误
# 正确答案是4.375
# 此题错误
# 正确答案是66
# 此题正确
# 正确答案是80
# 此题正确
# 正确答案是499
# 此题错误
# 正确答案是60
# 此题错误
# 正确答案是360
# 此题错误
# 正确答案是2
# 此题正确
# 正确答案是50
# 此题错误
# 正确答案是4
# 此题错误
# 正确答案是25%
# 此题正确
# 正确答案是37.5
# 此题错误
# 正确答案是312
# 此题错误
# 正确答案是76%
# 此题正确
# 正确答案是780
# 此题错误
# 正确答案是40
# 此题正确
# 正确答案是10.8
# 此题错误
# 正确答案是20
# 此题错误
# 正确答案是420
# 此题正确
# 正确答案是3
# 此题正确
# 正确答案是80
# 此题错误
# 正确答案是4
# 此题正确
# 正确答案是16700
# 此题错误
# 正确答案是((13)/(120))
# 此题错误
# 正确答案是12.5
# 此题正确
# 正确答案是192
# 此题错误
# 正确答案是22.5
# 此题错误
# 正确答案是3
# 此题正确
# 正确答案是50
# 此题错误
# 正确答案是6388.8
# 此题错误
# 正确答案是10%
# 此题错误
# 正确答案是3
# 此题正确
# 正确答案是18
# 此题错误
# 正确答案是60
# 此题错误
# 正确答案是5
# ...

# %%
def do_c3():
    with open('data/c3/dataclean.json','r') as f:
        data_all=json.load(f)
    ans=[];
    path='c3_gpt_saved.json'
    right=0;
    wrong=0
    for i in data_all:
        s='阅读这段对话，'
        choices=''
        for t in range(len(i[1][0]['choice'])):
            choices+=i[1][0]['choice'][t]+','
        s=s+i[1][0]['question']+"从选项"+choices+"选择一个\n"
        
        
        for t in range(len(i[0])):
            s=s+i[0][t]
        
        tmp,history=model.chat(tokenizer, s, history=[])
        ans.append(tmp)
        
        print("正确答案是"+i[1][0]["answer"])
        if(i[1][0]["answer"] in tmp):
            right=right+1
            print("此题正确")
        else:
            wrong=wrong+1
            print("此题错误")
    print(right*1.0/(right+wrong))
    print(right+wrong)
    with open(path,'w') as f:
        json.dump(ans,f);
        
do_c3();
print("DONE")
# Out:
# 正确答案是工作
# 此题正确
# 正确答案是买新设备
# 此题错误
# 正确答案是预订座位
# 此题正确
# 正确答案是男的就要到了
# 此题错误
# 正确答案是奥运会主会馆
# 此题正确
# 正确答案是工作任务多
# 此题错误
# 正确答案是不好
# 此题正确
# 正确答案是电影版《神话》
# 此题正确
# 正确答案是来接她
# 此题正确
# 正确答案是不够完美
# 此题正确
# 正确答案是查机票
# 此题正确
# 正确答案是照相机没电了
# 此题正确
# 正确答案是杂志编辑
# 此题正确
# 正确答案是医生
# 此题正确
# 正确答案是不限制使用对象
# 此题正确
# 正确答案是白色的楼
# 此题错误
# 正确答案是明星
# 此题正确
# 正确答案是还没结婚
# 此题错误
# 正确答案是小李的住房很贵
# 此题错误
# 正确答案是书画
# 此题正确
# 正确答案是家离工作单位太远
# 此题错误
# 正确答案是应该早点儿出发
# 此题正确
# 正确答案是感冒了
# 此题正确
# 正确答案是不想要这件
# 此题错误
# 正确答案是关灯
# 此题错误
# 正确答案是开会
# 此题正确
# 正确答案是请假
# 此题正确
# 正确答案是还在上学
# 此题错误
# 正确答案是要去做客
# 此题错误
# 正确答案是看房子
# 此题正确
# 正确答案是音乐声音很大
# 此题正确
# 正确答案是最好别离开
# 此题正确
# 正确答案是赢了
# 此题正确
# 正确答案是女的家乡气候湿润
# 此题错误
# 正确答案是医院
# 此题正确
# 正确答案是车上
# 此题错误
# 正确答案是抽烟了
# 此题正确
# 正确答案是弄掉了书页
# 此题正确
# 正确答案是称赞
# 此题正确
# 正确答案是上网
# 此题正确
# 正确答案是吃东西
# 此题错误
# 正确答案是2.2元
# 此题正确
# 正确答案是看过很多
# 此题正确
# 正确答案是很精彩
# 此题正确
# 正确答案是春天
# 此题错误
# 正确答案是80元一晚
# 此题错误
# 正确答案是想学习数学
# 此题错误
# 正确答案是环境好
# 此题正确
# 正确答案是两块五
# 此题错误
# 正确答案是惋惜
# 此题正确
# 正确答案是鼓励
# 此题正确
# 正确答案是小马
# 此题错误
# 正确答案是再跑一会儿
# 此题正确
# ...

# %%
def do_child():
    with open('data/chid/dataclean.json','r') as f:
        data_all=json.load(f)
    ans=[];
    path='chid_gpt_saved.json'
    right=0;
    wrong=0
    for i in data_all:
        s='阅读这段文字，'
        choices=''
        for t in range(len(i['candidates'])):
            for tj in range(len(i['candidates'][t])):
                
                choices+=i['candidates'][t][tj]+','
        s="从选项:"+choices+"选择一个适当的词语，替换句中的#idiom#,回答只需包含你选择的选项\n"
        s=s+i['content']
        
        tmp,history=model.chat(tokenizer, s, history=[])
        ans.append(tmp)
        
        print("正确答案是"+i['groundTruth'][0])
        if(i['groundTruth'][0] in tmp):
            right=right+1
            print("此题正确")
        else:
            wrong=wrong+1
            print("此题错误")
#     print(right*1.0/(right+wrong))
#     print(right+wrong)
    with open(path,'w') as f:
        json.dump(ans,f);
        
do_child();
# Out:
# 正确答案是深恶痛绝
# 此题错误
# 正确答案是杂乱无章
# 此题正确
# 正确答案是磨刀霍霍
# 此题错误
# 正确答案是独一无二
# 此题正确
# 正确答案是品头题足
# 此题错误
# 正确答案是大同小异
# 此题正确
# 正确答案是罪魁祸首
# 此题错误
# 正确答案是聪明才智
# 此题错误
# 正确答案是千载难逢
# 此题错误
# 正确答案是酸甜苦辣
# 此题错误
# 正确答案是出乎意料
# 此题错误
# 正确答案是一目了然
# 此题错误
# 正确答案是无可奈何
# 此题正确
# 正确答案是长此以往
# 此题错误
# 正确答案是燃眉之急
# 此题正确
# 正确答案是蹑手蹑脚
# 此题错误
# 正确答案是破釜沈舟
# 此题错误
# 正确答案是一吐为快
# 此题正确
# 正确答案是字里行间
# 此题正确
# 正确答案是子虚乌有
# 此题错误
# 正确答案是天翻地覆
# 此题正确
# 正确答案是足不出户
# 此题正确
# 正确答案是截然不同
# 此题错误
# 正确答案是如梦初醒
# 此题正确
# 正确答案是自作自受
# 此题错误
# 正确答案是不相上下
# 此题错误
# 正确答案是风吹草动
# 此题错误
# 正确答案是凶神恶煞
# 此题错误
# 正确答案是铤而走险
# 此题正确
# 正确答案是远走高飞
# 此题错误
# 正确答案是一生一世
# 此题错误
# 正确答案是若有所思
# 此题错误
# 正确答案是载歌载舞
# 此题错误
# 正确答案是津津乐道
# 此题正确
# 正确答案是错落有致
# 此题正确
# 正确答案是义愤填胸
# 此题错误
# 正确答案是按部就班
# 此题正确
# 正确答案是拖泥带水
# 此题正确
# 正确答案是生吞活剥
# 此题正确
# 正确答案是掷地金声
# 此题错误
# 正确答案是趾高气扬
# 此题错误
# 正确答案是一丝不苟
# 此题错误
# 正确答案是水泄不通
# 此题正确
# 正确答案是大功告成
# 此题错误
# 正确答案是汪洋大海
# 此题错误
# 正确答案是鸡毛蒜皮
# 此题正确
# 正确答案是彻头彻尾
# 此题错误
# 正确答案是喜出望外
# 此题正确
# 正确答案是终身大事
# 此题错误
# 正确答案是循序渐进
# 此题正确
# 正确答案是一家老小
# 此题错误
# 正确答案是视而不见
# 此题错误
# 正确答案是朝夕相处
# ...

# %%
def do_generation():
    with open('data/generation/dataclean.json','r') as f:
        data_all=json.load(f)
    ans=[];
    path='generation_chatglm_saved.json'
    right=0;
    wrong=0
    for i in data_all:
        
        s=i['question']
        tmp,history=model.chat(tokenizer, s, history=[])
        print(tmp)
        ans.append(tmp)
        
#         print("正确答案是"+i['groundTruth'][0])
#         if(i['groundTruth'][0] in tmp):
#             right=right+1
#             print("此题正确")
#         else:
#             wrong=wrong+1
#             print("此题错误")
#     print(right*1.0/(right+wrong))
#     print(right+wrong)
    with open(path,'w') as f:
        json.dump(ans,f);
        
do_generation();
# Out:
# 小李杜是指李商隐和杜甫。李商隐和杜甫都是唐代著名的诗人，被誉为“大李杜”之下的两位杰出诗人。
# 80年代电视剧《霍元甲》主题曲是《万里长城长》
#
# 《万里长城长》是由张明敏演唱的一首歌曲，收录于1984年专辑《中华英豪》中。该歌曲是电视剧《霍元甲》的主题曲，歌词描述了霍元甲在万里长城上的故事。
# 张艺谋电影《英雄》中秦始皇的扮演者是中国内地男演员陈坤。
# 世界三大饮料是茶、可可和咖啡。
# 旦是专门指女性角色的。旦，指戏曲中的女角，包括生、旦、净、末、丑等角色类别。其中，旦是女角的主要角色类型，通常扮演艳丽、优美、娇艳、妩媚、温柔等形象。
# 抽筋通常是指肌肉痉挛，是一种肌肉自我调节的反应，通常是由于身体缺乏某些元素所致。以下是一些常见的元素，如果它们缺失过多，可能会导致抽筋：
#
# 1. 钙：钙是骨骼和肌肉的主要成分，如果身体缺乏足够的钙，可能会导致肌肉痉挛。
#
# 2. 镁：镁是另一种重要的元素，与钙一起作用来帮助肌肉和神经正常功能。如果身体缺乏足够的镁，也可能导致抽筋。
#
# 3. 钾：钾是一种重要的矿物质，可以帮助平衡体内的电解质，防止肌肉痉挛。
#
# 4. 磷：磷是骨骼和牙齿的主要成分，如果身体缺乏足够的磷，可能会导致钙流失，引起抽筋。
#
# 5. 维生素D：维生素D可以帮助身体吸收和利用钙，如果身体缺乏足够的维生素D，也可能导致抽筋。
#
# 需要注意的是，不同人的抽筋原因可能不同，因此可能存在其他元素缺乏的原因。如果经常抽筋，建议咨询医生，确定具体原因并获得适当的治疗建议。
# 向蔺相如负荆请罪的名将是廉颇。
# 清代也是中国古代第一部以"字典"命名的汉字辞书叫做《康熙字典》。它是清朝康熙帝在位期间(1668-1722)编纂的一部综合性汉字辞书，收录了大量的汉字、词语、成语和常用语，并进行了详细的解释和分类。这部字典在中国汉字研究史上具有重要的地位，被誉为"汉字的百科全书"。
# 中国民间四大爱情传说是《梁祝》《白蛇传》《孟姜女》和《牛郎织女》。
# "白衣天使"通常指的是医生。医生是从事医疗工作的职业之一，他们通过诊断、治疗和照顾患者，提供医疗服务和保障患者的健康。在中国文化中，医生被视为英雄和天使，因此"白衣天使"一词通常用来形容他们的职业和形象。
# 日本动画片《名侦探柯南》中为柯南设计多种道具的博士名叫青山刚昌。
# ...
